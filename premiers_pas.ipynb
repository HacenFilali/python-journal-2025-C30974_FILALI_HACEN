# %% [markdown]
# PHD PYTHON DR.BENANI TP
#
# ---
#
# # Étape 1 – Installation de Python
# Installation du distribiteur  *Anaconda*                  Done ✅
#
# # Étape 2 – Prise en main de l’environnement
#
# 1. Ouverture de Google *Colab*                        Done ✅
# 2. Création  du fichier `premiers_pas.ipynb`           Done ✅
#
#
# ```python

# %% [markdown]
# # Exercice 1 : Afficher votre nom
# print("Bonjour, je m'appelle ...")

# %%
print("Bonjour, je m'appelle EL Hacen Ahmed Salem EL FILALI")
# Out:
# Bonjour, je m'appelle EL Hacen Ahmed Salem EL FILALI

# %% [markdown]
# Done ✅

# %% [markdown]
# # Exercice 2 : Effectuer quelques calculs
# a = 5
# b = 2
# print("a + b =", a + b)

# %%
a = 5
b = 2
print("a + b =", a + b)
# Out:
# a + b = 7

# %% [markdown]
# Done ✅

# %% [markdown]
# # Exercice 3 : Travailler avec une liste
# nombres = [1, 2, 3, 4]
# for n in nombres:
#     print(n * 2)

# %%
nombres = [1, 2, 3, 4]
for n in nombres:
  print(n * 2)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# Done ✅
