# %% [markdown]
# # Réponse question Étape 3 CODE/SEMMAINE 1
# 1- on'a utiliser L’environnement Anaconda parceque :il contient les IDE (Pandas,jupyte,spyder,vs code ,pycharm)
# 2- on'a utiliser L’environnement Colab Parceque : il nous permet l'Analyse et la visualisation des  données efficase il nous donne la  possibilité de partager les notebooks et les fichiers via un lien dans mon dépôt GITHUB.
# [Google colab](https://colab.research.google.com/).
#
# 3- les taches acomplie : Installation de la distribution Anaconda et Son Processus
# - Collect des donneés
# - Traitement
# - Visualisation (Resultat) avec la verification et Ipmortation des IDE SPYDER,Pandas,Numpy,Matplotlib et Ouverture de la plateforme  Google Colab , Création du fichier premiers_pas.ipynb, Afficher mon nom , En Effectueant quelques calculs y compris le travail sur une liste.
#
# 4- Mes Impression générales : Decouvrire le language Python en calcul scientifique et trouvé des solutions en python pour mes recherches en AI

# %% [markdown]
# # Réponse question Étape 4 – Résumé réflexif (Groupe 1)
#
# 1. Résumé de ce que nous avons fait dans la premiere  semaine de la formtion: Introduction sur Python (Distribiteur Anaconda Et Distribiteur Standart )
#  - les Bases (Variable , Expression et Instriction )
#  - Standart (Stricture Centrale , Boucle et Fonction)
#  - Pariadiaque (Fonction , Orienté Objet et Multiparadiale).
#  1.1 Les caracteristiques du Programme (POO/MOO) :
# - Classe / Objet
# - Encapsulation
# - Heritage
# - Polymorphisme
#  1.2 La recherche Scientifique ( Article 1,2 et 3) Methode Americaine
#  - Problematique
#  - Approche et
#  - Prespective
#  1.3 Genie Logiciel
# - Specification
# - Conception
# - Implamentation
# - Test
#
# 2. Résumé de ce que nous avons apris les notions et les mots Clé que j'ai appris cette semaine :
# - Python
# - pandas
# - spyder
# - Numpy
# - Matplotlib
# - Pycharm
# - Distrubition Anaconda
# - Navigateur Anaconda
# - Google Colab
# - JupyterLite
#
# 3. Les attentes des prochaines semaines de la formation :
#   - Avoir plus d'Information et d'apprentissage sur environement DIS-Anaconda et les API spyder et Matplotlib.
#   - Un approfondissement sur le language PYTHON.
#
# 4. Les difficultés rencontrées :
# - Creation d'un Dossier via ligne de commande
# - Partage link  de mon dépôt via Google colab
# - des difficulté en essayant la procedure Virtualisation via INVITE Cmd pour le partage du fichier G.Colab.

# %% [markdown]
# # Merci
