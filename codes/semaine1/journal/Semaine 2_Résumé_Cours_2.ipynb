# %% [markdown]
# **# Résumé Cours 2**
# ---
# 1. Problématique
#
# *   Domaine
# *   Axe
# *  review
# Approche
# ---
# AI MOJO
#
# ---
#
#
# *   DATA (Pandas)
# *   Traitement (Numpy)
# *   Visualisation (Matpolib)
#
# 2. La conception de la collecte de données
#   2.1 BDD
#
# *  SGBD SQL
#   - Mysql
#   - SqLite
#   - Postgresql
#
# *   SGBD NoSQL
#   - Document ( MongoDB)
#   - Colone (Cassandra)
#   - Neoj.
#
#   2.2 Fichier (Document)
#  - XML
#  - jsm
#  - CSV
#
#   2.3 Web
#
# *   Classique
#   - Statistique Architect  2 Tiers ( Client - Serveur )
#   - Dynamique Architect 3 Tiers ( Client - Serveur Web - Serveur BD )
#
#
# *   Service Web MS (Architect Monolithique)
