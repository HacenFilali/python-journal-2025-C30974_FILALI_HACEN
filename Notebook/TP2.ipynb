# %% [markdown]
#  **TP 2 Semaine_2**
# 1. Pandas
#   - Importing Pandas

# %%
import pandas as pd # Importing Pandas
import matplotlib.pyplot as plt # Importing matplotlib for visualisation

# %% [markdown]
# Done ✅

# %% [markdown]
#      - Reading CSV Files

# %%
df = pd.read_csv('../DATA/pokemon_data.csv')

# %% [markdown]
# # df-DataFrame
#
# ![liste DATA.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# ## **2. iloc[] function**

# %%
print(df.head())
df.head().plot.bar()  #   Affiche les 5 première lignes
df.iloc[2, 4] # Here we can see the information from second row and fourth␣ ↪colum
df.iloc[:5, :5] # Here is the information of first five rows with first five␣↪column

# %% [markdown]
# 5 Lignes

# %% [markdown]
# ![head.png](data:image/png;base64,...)

# %% [markdown]
# # <Axes: >

# %%
df.iloc[:5, 1:5].plot.bar() # Bar char of the DataFrame provided above

# %% [markdown]
# ![Axes.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %%
print(df.head())
df.head().plot.bar()  #   Affiche les 5 première lignes
print(df.head(2))
df.iloc[5]
print(df.iloc[5])

# %% [markdown]
# ![colone 5.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %%
print(df.head())
df.head().plot.bar()  #   Affiche les 5 première lignes
print(df.head(2))
df.iloc[[5]]
print(df.iloc[[5]])

# %% [markdown]
# ![clonnes.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %%
df
print(df.head())
df.head().plot.bar()  #   Affiche les 5 première lignes
print(df.head(2))
df.iloc[:, 1] # Filters all rows and "Name" column as Series
print(df.iloc[:, 1])

# %% [markdown]
# Affiche
#
# ![1111.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %%
df
print(df.head())
df.iloc[:, [1, 6]] # Filters all rows and "Name" and "Defense" columns as␣↪DataFram
print(df.iloc[:, [1, 6]])

# %% [markdown]
# ![1111.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# <Axes: ylabel='Frequency'>

# %%
df
print(df.head())
df.iloc[:, [1, 6]].plot.hist() # Histogram of defence data
print(df.shape)
print(df.columns)

# %% [markdown]
# ![graa.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# Multiple filtering

# %%
df.loc[df['Legendary'] == False] # Filter rows where value of "Legendary"␣
 ↪column is Fals
 df.loc[
 (df['Legendary'] == False)
 & (df['Type 1'] == 'Grass')
 ]
 df.loc[
 ~((df['Type 1'] == 'Grass')
 & (df['Legendary'] == False)

# %% [markdown]
# ![legendry.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# ![vcgggg.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# # 3 Query() method

# %%
 df.query('(HP > 40) and (Attack < 100)')
 min_hp = 70
 df.query('(HP > @min_hp)')

# %% [markdown]
# ![ph.png](data:image/png;base64,...)

# %% [markdown]
# Done ✅

# %% [markdown]
# # **FIN**
